# %% [markdown]
# Diferente do processo de ETL, no ELT, os dados são carregados diretamente, da maneira que foram extraídos e a transformação é feita por comandos SQL, posteriormente.

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# %% [markdown]
# # Extração dos dados e Load

# %%
# Configuração do Banco de Dados

usuario_db = 'postgres'
senha_db = '254535'
host_db = 'localhost'
porta_db = '5432'
nome_banco_db = 'elt_BD'

# String de Conexão PostgreSQL
DATABASE_URL = f'postgresql://{usuario_db}:{senha_db}@{host_db}:{porta_db}/{nome_banco_db}'

print(f"Tentando conectar em: {host_db}:{porta_db}/{nome_banco_db}...")

try:
    # Criando a engine
    engine = create_engine(DATABASE_URL)

    with engine.connect() as conn: # apenas para teste de conexão
        conn.execute(text("SELECT 1"))

    print("Conexão com PostgreSQL configurada com sucesso!")

except Exception as e:
    print(f"\n ERRO NA CARGA DO BANCO!")
    print(f"Detalhe do erro: {e}")
# Out:
# Tentando conectar em: localhost:5432/elt_BD...
# Conexão com PostgreSQL configurada com sucesso!

# %%
# Extract & load dos arquivos

arquivos = {
    '2022': 'data/156_2022.csv',
    '2024': 'data/156_2024.csv',
    '2025': 'data/156_2025.csv'
}

# Limpeza inicial para garantir que não haja dados duplicados
with engine.begin() as conn:
    conn.execute(text("DROP TABLE IF EXISTS raw_chamados_156 CASCADE;"))

# Loop de carga
for ano, arquivo in arquivos.items():
    try:
        encoding = 'utf-8' if ano == '2022' else 'latin1'
        sep = ';'
        
        # Lê o CSV como texto, forçando tudo como string para evitar erros de tipo no load inicial
        df_raw = pd.read_csv(arquivo, sep=sep, encoding=encoding, dtype=str)

        # Força todos os nomes das colunas a serem minúsculos para não ocorrer erros nas chamadas
        df_raw.columns = df_raw.columns.str.lower()
        # Coluna de rastreamento
        df_raw['ano_origem'] = ano
        
        # Vai empilhando os dados dos anos
        df_raw.to_sql('raw_chamados_156', con=engine, if_exists='append', index=False)
        
        print(f"Dados de {ano} carregados para a tabela 'raw_chamados_156'.")
        
    except Exception as e:
        print(f"Erro no ano {ano}: {e}")
# Out:
# Dados de 2022 carregados para a tabela 'raw_chamados_156'.
# Dados de 2024 carregados para a tabela 'raw_chamados_156'.
# Dados de 2025 carregados para a tabela 'raw_chamados_156'.

# %% [markdown]
# # Transformação dos dados

# %% [markdown]
# **Criando as dimensões**
# - Dimensão serviço (gruposervico_codigo, gruposervico_descricao, servico_codigo, servico_descricao)
# - Dimensão localização (logradouro, numero, bairro, rpa, latitude, longitude)
# - Dimensão situacao (situacao)
# - Dimensão tempo (dia, mes, ano, trimestre)
#
# > Durante a execução das *queries* de criação, aplicaremos funções de tratamento e conversão em SQL para garantir a qualidade dos dados finais.

# %%
with engine.begin() as conn:
    # Utilização da extensão unaccent do Postgres para remover acentos
    # Verifica se não há erro na utilização da extensão
    try:
        conn.execute(text("CREATE EXTENSION IF NOT EXISTS unaccent;"))
        print("Extensão unaccent habilitada (limpeza de acentos ativa)")
    except Exception as e:
        print("Extensão unaccent não disponível. A limpeza de acentos será ignorada.")


    # 1. Criação da Dimensão Serviço
    conn.execute(text("""
        DROP TABLE IF EXISTS dim_servico CASCADE;
        
        CREATE TABLE dim_servico AS
        SELECT DISTINCT
            -- Criação do ID - chave primária substituta
            ROW_NUMBER() OVER (ORDER BY servico_descricao) as id_servico,
            
            gruposervico_codigo,
            -- Padronização para caixa alta e remoção de espaços extras
            UPPER(TRIM(gruposervico_descricao)) as gruposervico_descricao,
                      
            servico_codigo,
            UPPER(TRIM(servico_descricao)) as servico_descricao
        
        FROM raw_chamados_156
        WHERE servico_descricao IS NOT NULL;
    """))

    # 2. Criação da Dimensão Localização
    conn.execute(text("""
        DROP TABLE IF EXISTS dim_localizacao CASCADE;
        
        CREATE TABLE dim_localizacao AS
        SELECT DISTINCT
            -- Criação do ID - chave primária substituta
            ROW_NUMBER() OVER (ORDER BY bairro, logradouro) as id_localizacao,
            
            -- Inclusão dos elementos, além da padronização
            UPPER(TRIM(bairro)) as bairro,
            rpa,
            UPPER(TRIM(logradouro)) as logradouro
            
        FROM raw_chamados_156
        WHERE bairro IS NOT NULL;          
    """))

    # 3. Criação da Dimensão Situação
    conn.execute(text("""
        DROP TABLE IF EXISTS dim_situacao CASCADE;
        
        CREATE TABLE dim_situacao AS
        SELECT DISTINCT
            -- Criação do ID - chave primária substituta
            ROW_NUMBER() OVER (ORDER BY situacao) as id_situacao,
            
            -- Inclusão de situação, além da padronização dos dados
            UPPER(TRIM(situacao)) as situacao
            
        FROM raw_chamados_156
        WHERE situacao IS NOT NULL;     
    """))

    # 4. Criação da Dimensão Tempo
    conn.execute(text("""
        DROP TABLE IF EXISTS dim_tempo CASCADE;
        
        CREATE TABLE dim_tempo AS
        WITH todas_datas AS (
            -- Pega datas de solicitação
            SELECT CAST(data_demanda AS DATE) as data_ref 
            FROM raw_chamados_156 
            WHERE data_demanda IS NOT NULL
            UNION
            -- Pega datas de finalização
            SELECT CAST(data_ult_situacao AS DATE) as data_ref 
            FROM raw_chamados_156 
            WHERE data_ult_situacao IS NOT NULL
        )
        SELECT DISTINCT
            -- Criação do ID - chave primária substituta
            ROW_NUMBER() OVER (ORDER BY data_ref) as id_tempo,
            data_ref as data_completa,
            
            -- Extração de atributos de data
            EXTRACT(DAY FROM data_ref) as dia,
            EXTRACT(MONTH FROM data_ref) as mes,
            EXTRACT(YEAR FROM data_ref) as ano,
            EXTRACT(QUARTER FROM data_ref) as trimestre,
            
            -- Nome do dia da semana
            TO_CHAR(data_ref, 'Day') as dia_semana
            
        FROM todas_datas;         
    """))
# Out:
# Extensão unaccent habilitada (limpeza de acentos ativa)

# %%
with engine.begin() as conn:
    # Aplicando chaves primárias às dimensões
    conn.execute(text("ALTER TABLE dim_servico ADD PRIMARY KEY (id_servico);"))
    conn.execute(text("ALTER TABLE dim_localizacao ADD PRIMARY KEY (id_localizacao);"))
    conn.execute(text("ALTER TABLE dim_situacao ADD PRIMARY KEY (id_situacao);"))
    conn.execute(text("ALTER TABLE dim_tempo ADD PRIMARY KEY (id_tempo);"))

    #criando indices auxiliares funcionais na tabela raw para tentar melhor performance
    conn.execute(text("CREATE INDEX IF NOT EXISTS idx_raw_servico_full ON raw_chamados_156(servico_codigo, (UPPER(TRIM(servico_descricao))));"))
    conn.execute(text("CREATE INDEX IF NOT EXISTS idx_raw_bairro_func ON raw_chamados_156((UPPER(TRIM(bairro))));"))
    conn.execute(text("CREATE INDEX IF NOT EXISTS idx_raw_lograd_func ON raw_chamados_156((UPPER(TRIM(logradouro))));"))
    conn.execute(text("CREATE INDEX IF NOT EXISTS idx_raw_situacao_func ON raw_chamados_156((UPPER(TRIM(situacao))));"))
    conn.execute(text("CREATE INDEX IF NOT EXISTS idx_raw_data_demanda ON raw_chamados_156(data_demanda);"))
    conn.execute(text("CREATE INDEX IF NOT EXISTS idx_raw_data_ult ON raw_chamados_156(data_ult_situacao);"))

# %% [markdown]
# **A tabela Fato do Esquema Estrela**
# - Nesta etapa, unificamos os dados brutos com as chaves das dimensões e calculamos as métricas principais do negócio: volume, taxa de resolução e tempo médio de atendimento.

# %%
with engine.begin() as conn:
    print("Criando índices de busca nas dimensões...")
    
    # Índices para acelerar o JOIN nas dimensões
    
    conn.execute(text("CREATE INDEX IF NOT EXISTS idx_dim_servico_busca ON dim_servico(servico_codigo, servico_descricao);"))

    conn.execute(text("CREATE INDEX IF NOT EXISTS idx_dim_localizacao_busca ON dim_localizacao(bairro, logradouro);"))

    conn.execute(text("CREATE INDEX IF NOT EXISTS idx_dim_situacao_busca ON dim_situacao(situacao);"))

    conn.execute(text("CREATE INDEX IF NOT EXISTS idx_dim_tempo_busca ON dim_tempo(data_completa);"))

    conn.execute(text("ANALYZE dim_servico, dim_localizacao, dim_situacao, dim_tempo, raw_chamados_156;"))
    
    print("Índices criados e estatísticas atualizadas com sucesso!")
# Out:
# Criando índices de busca nas dimensões...
# Índices criados e estatísticas atualizadas com sucesso!

# %%
import time
start_time = time.time()

with engine.begin() as conn:
    
    print("1. Criando tabela Staging (Limpando dados brutos)...")
    conn.execute(text("DROP TABLE IF EXISTS staging_chamados CASCADE;"))
    
    conn.execute(text("""
        CREATE TABLE staging_chamados AS
        SELECT
            ano_origem,
            -- Limpeza centralizada (UPPER + TRIM)
            UPPER(TRIM(servico_descricao)) as join_servico,
            servico_codigo,
            UPPER(TRIM(bairro)) as join_bairro,
            UPPER(TRIM(logradouro)) as join_logradouro,
            UPPER(TRIM(situacao)) as join_situacao,
            
            -- Tratamento de datas
            CAST(data_demanda AS DATE) as data_demanda_clean,
            CAST(data_ult_situacao AS DATE) as data_ult_situacao_clean,
            situacao as situacao_original
        FROM raw_chamados_156;
    """))
    
    # Índices na Staging
    conn.execute(text("CREATE INDEX idx_stg_join_servico ON staging_chamados(servico_codigo, join_servico);"))
    conn.execute(text("CREATE INDEX idx_stg_join_local ON staging_chamados(join_bairro, join_logradouro);"))
    
    print("2. Recriando Dimensões sem duplicatas...")
    
    # Dimensão Serviço Corrigida
    conn.execute(text("DROP TABLE IF EXISTS dim_servico CASCADE;"))
    conn.execute(text("""
        CREATE TABLE dim_servico AS
        SELECT
            ROW_NUMBER() OVER (ORDER BY join_servico) as id_servico,
            servico_codigo,
            join_servico as servico_descricao,
            -- Pega o primeiro grupo que aparecer (evita duplicação)
            MAX(gruposervico_codigo) as gruposervico_codigo, 
            MAX(UPPER(TRIM(gruposervico_descricao))) as gruposervico_descricao
        FROM (
            SELECT DISTINCT servico_codigo, UPPER(TRIM(servico_descricao)) as join_servico, gruposervico_codigo, gruposervico_descricao
            FROM raw_chamados_156
        ) sub
        GROUP BY servico_codigo, join_servico; -- Agrupa para garantir 1 linha por serviço
    """))
    conn.execute(text("CREATE INDEX idx_dim_servico_join ON dim_servico(servico_codigo, servico_descricao);"))

    # Dimensão Localização Corrigida
    conn.execute(text("DROP TABLE IF EXISTS dim_localizacao CASCADE;"))
    conn.execute(text("""
        CREATE TABLE dim_localizacao AS
        SELECT
            ROW_NUMBER() OVER (ORDER BY join_bairro, join_logradouro) as id_localizacao,
            join_bairro as bairro,
            join_logradouro as logradouro,
            MAX(rpa) as rpa -- Se houver conflito de RPA, pega o maior
        FROM (
            SELECT DISTINCT UPPER(TRIM(bairro)) as join_bairro, UPPER(TRIM(logradouro)) as join_logradouro, rpa
            FROM raw_chamados_156
        ) sub
        WHERE join_bairro IS NOT NULL
        GROUP BY join_bairro, join_logradouro; -- A chave do sucesso: Agrupar bairro e rua
    """))
    conn.execute(text("CREATE INDEX idx_dim_local_join ON dim_localizacao(bairro, logradouro);"))

    # Dimensão Situação
    conn.execute(text("DROP TABLE IF EXISTS dim_situacao CASCADE;"))
    conn.execute(text("""
        CREATE TABLE dim_situacao AS
        SELECT ROW_NUMBER() OVER (ORDER BY situacao) as id_situacao, situacao
        FROM (SELECT DISTINCT UPPER(TRIM(situacao)) as situacao FROM raw_chamados_156) sub;
    """))
    
    # Dimensão Tempo
    conn.execute(text("DROP TABLE IF EXISTS dim_tempo CASCADE;"))
    conn.execute(text("""
        CREATE TABLE dim_tempo AS
        WITH todas_datas AS (
            SELECT CAST(data_demanda AS DATE) as data_ref FROM raw_chamados_156
            UNION
            SELECT CAST(data_ult_situacao AS DATE) as data_ref FROM raw_chamados_156
        )
        SELECT 
            ROW_NUMBER() OVER (ORDER BY data_ref) as id_tempo,
            data_ref as data_completa,
            EXTRACT(DAY FROM data_ref) as dia,
            EXTRACT(MONTH FROM data_ref) as mes,
            EXTRACT(YEAR FROM data_ref) as ano,
            EXTRACT(QUARTER FROM data_ref) as trimestre,
            TO_CHAR(data_ref, 'Day') as dia_semana
        FROM todas_datas WHERE data_ref IS NOT NULL;
    """))

  # criando a tabela fato
    print("3. Criando Tabela Fato Final...")
    conn.execute(text("DROP TABLE IF EXISTS fato_chamados CASCADE;"))
    
    conn.execute(text("""
        CREATE TABLE fato_chamados AS
        SELECT 
            s.id_servico,
            l.id_localizacao,
            sit.id_situacao,
            t_ini.id_tempo as id_tempo_inicio,
            t_fim.id_tempo as id_tempo_fim,
            r.ano_origem,
            
            -- Métricas
            CASE WHEN r.join_situacao = 'ATENDIDA' THEN 1 ELSE 0 END as is_resolvido,
            CASE 
                WHEN r.join_situacao = 'ATENDIDA' AND r.data_ult_situacao_clean IS NOT NULL 
                THEN (r.data_ult_situacao_clean - r.data_demanda_clean)
                ELSE NULL 
            END as dias_para_conclusao

        FROM staging_chamados r
        LEFT JOIN dim_servico s 
            ON r.servico_codigo = s.servico_codigo 
            AND r.join_servico = s.servico_descricao
        LEFT JOIN dim_localizacao l 
            ON r.join_bairro = l.bairro 
            AND r.join_logradouro = l.logradouro
        LEFT JOIN dim_situacao sit ON r.join_situacao = sit.situacao
        LEFT JOIN dim_tempo t_ini ON r.data_demanda_clean = t_ini.data_completa
        LEFT JOIN dim_tempo t_fim ON r.data_ult_situacao_clean = t_fim.data_completa;
    """))
    
    print(f"SUCESSO! Processo concluído em {round(time.time() - start_time, 2)} segundos.")
# Out:
# 1. Criando tabela Staging (Limpando dados brutos)...
# 2. Recriando Dimensões sem duplicatas...
# 3. Criando Tabela Fato Final...
# SUCESSO! Processo concluído em 5.93 segundos.

# %%
df_analise = pd.read_sql("SELECT * FROM fato_chamados LIMIT 20", engine)
df_visualizacao = df_analise.copy()

# Preenche os vazios com o texto
df_visualizacao['dias_para_conclusao'] = df_visualizacao['dias_para_conclusao'].fillna('EM ANDAMENTO')
df_visualizacao['is_resolvido'] = df_visualizacao['is_resolvido'].map({0: 'NÃO', 1: 'SIM'})
display(df_visualizacao.head(20))
# Out:
#     id_servico  id_localizacao  id_situacao  id_tempo_inicio  id_tempo_fim  \
# 0           50            4723            3                1          3079
# 1           50            7954            3                2          3088
# 2           50            7954            3                3          3088
# 3           50            5908            3                4          3088
# 4           50            9916            3                5          3088
# 5           50            3054            3                6          3088
# 6          103            2491            1                7          2862
# 7          151           10097            1                8          2869
# 8          151           13607            1                9          2879
# 9          103            9795            1               10          3082
# 10         151           10131            1               11          3358
# 11         103            3596            1               12          2867
# 12         103           13658            1               13          2872
# 13          89           12561            3               14          3120
# 14         151            5670            1               15          2872
# 15         151            2830            1               16          2872
# 16         103           13722            1               17          2872
# 17         103            2776            1               18          2872
# 18         103            5654            1               18          2872
# 19         103            2803            1               19          2867
#
#    ano_origem is_resolvido dias_para_conclusao
# 0        2024          NÃO        EM ANDAMENTO
# 1        2024          NÃO        EM ANDAMENTO
# 2        2024          NÃO        EM ANDAMENTO
# 3        2024          NÃO        EM ANDAMENTO
# 4        2024          NÃO        EM ANDAMENTO
# 5        2024          NÃO        EM ANDAMENTO
# 6        2024          SIM              5118.0
# 7        2024          SIM              5112.0
# 8        2024          SIM              5082.0
# 9        2024          SIM              5239.0
# 10       2025          SIM              5496.0
# 11       2024          SIM              4937.0
# 12       2024          SIM              4926.0
# 13       2024          NÃO        EM ANDAMENTO
# 14       2024          SIM              4877.0
# 15       2024          SIM              4863.0
# 16       2024          SIM              4849.0
# 17       2024          SIM              4717.0
# 18       2024          SIM              4717.0
# 19       2024          SIM              4619.0
