# %% [markdown]
# Diferente do processo de ETL, no ELT, os dados são carregados diretamente, da maneira que foram extraídos e a transformação é feita por comandos SQL, posteriormente.

# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # Extração dos dados e Load

# %%
# Configuração do Banco de Dados
engine = create_engine('sqlite:///emlurb_data.db')

arquivos = {
    '2022': 'data/156_2022.csv',
    '2024': 'data/156_2024.csv',
    '2025': 'data/156_2025.csv'
}

for ano, arquivo in arquivos.items():
    try:
        encoding = 'utf-8' if ano == '2022' else 'latin1'
        sep = ';'
        
        # Lê o CSV como texto, forçando tudo como string para evitar erros de tipo no load inicial
        df_raw = pd.read_csv(arquivo, sep=sep, encoding=encoding, dtype=str)
        
        df_raw['ano_origem'] = ano
        
        # 'if_exists="append"' vai empilhando os dados dos anos
        df_raw.to_sql('raw_chamados_156', con=engine, if_exists='append', index=False)
        
        print(f"Dados de {ano} carregados para a tabela 'raw_chamados_156'.")
        
    except Exception as e:
        print(f"Erro no ano {ano}: {e}")
# Out:
# Dados de 2022 carregados para a tabela 'raw_chamados_156'.
# Dados de 2024 carregados para a tabela 'raw_chamados_156'.
# Dados de 2025 carregados para a tabela 'raw_chamados_156'.

# %% [markdown]
# # Transformação dos dados

# %%
from sqlalchemy import text

# 1. Apagamos a View anterior que estava com erro
with engine.connect() as conn:
    conn.execute(text("DROP VIEW IF EXISTS view_chamados_tratados;"))
    print("View antiga removida.")

# 2. Recriamos a View, mas agora gerando o ID (ROW_NUMBER) e calculando a Duração
query_criacao_view_corrigida = """
CREATE VIEW view_chamados_tratados AS
SELECT
    -- GERA UM ID SEQUENCIAL AUTOMATICAMENTE
    ROW_NUMBER() OVER (ORDER BY DATA_DEMANDA) as _id,
    
    UPPER(GRUPOSERVICO_DESCRICAO) as gruposervico_descricao,
    UPPER(SERVICO_DESCRICAO) as servico_descricao,
    COALESCE(NULLIF(NUMERO, ''), 'S/N') as numero_tratado,
    COALESCE(NULLIF(LATITUDE, ''), 'INDETERMINADO') as latitude_tratada,
    DATA_DEMANDA,
    DATA_ULT_SITUACAO,
    
    -- Coluna RESOLVIDO
    CASE 
        WHEN SITUACAO = 'ATENDIDA' THEN 1 
        ELSE 0 
    END as resolvido,

    -- Coluna DURAÇÃO (Cálculo de dias no SQLite)
    -- JulianDay converte datas para números, permitindo subtração
    CASE 
        WHEN SITUACAO = 'ATENDIDA' THEN 
            CAST(julianday(DATA_ULT_SITUACAO) - julianday(DATA_DEMANDA) AS INTEGER)
        ELSE NULL 
    END as dias_decorridos

FROM raw_chamados_156;
"""

with engine.connect() as conn:
    conn.execute(text(query_criacao_view_corrigida))
    print("View corrigida criada com sucesso!")
# Out:
# View antiga removida.
# View corrigida criada com sucesso!

# %%
df_analise = pd.read_sql("SELECT * FROM view_chamados_tratados LIMIT 20", engine)
display(df_analise)
# Out:
#     _id gruposervico_descricao  \
# 0     1                  POSTE
# 1     2                  POSTE
# 2     3                  POSTE
# 3     4                  POSTE
# 4     5                  POSTE
# 5     6                  POSTE
# 6     7                  POSTE
# 7     8                  POSTE
# 8     9                  POSTE
# 9    10                  POSTE
# 10   11                  POSTE
# 11   12                  POSTE
# 12   13              ESCADARIA
# 13   14              ESCADARIA
# 14   15              ESCADARIA
# 15   16              ESCADARIA
# 16   17              ESCADARIA
# 17   18              ESCADARIA
# 18   19              ESCADARIA
# 19   20              ESCADARIA
#
#                                     servico_descricao        numero_tratado  \
# 0                                IMPLANTACAO DE POSTE  7
# 1                                IMPLANTACAO DE POSTE  7
# 2                                IMPLANTACAO DE POSTE  50
# 3                                IMPLANTACAO DE POSTE  50
# 4                                IMPLANTACAO DE POSTE  00
# 5                                IMPLANTACAO DE POSTE  00
# 6                                IMPLANTACAO DE POSTE  200
# 7                                IMPLANTACAO DE POSTE  200
# 8                                IMPLANTACAO DE POSTE  09
# 9                                IMPLANTACAO DE POSTE  09
# 10                               IMPLANTACAO DE POSTE  54
# 11                               IMPLANTACAO DE POSTE  54
# 12  MANUTENCAO RECUPERACAO DE ESCADARIA, CANALETA ...  07
# 13  MANUTENCAO RECUPERACAO DE ESCADARIA, CANALETA ...  07
# 14                    RECUP. DE CANALETA DE ESCADARIA  30
# 15                    RECUP. DE CANALETA DE ESCADARIA  30
# 16                    RECUP. DE CANALETA DE ESCADARIA  6196
# 17                    RECUP. DE CANALETA DE ESCADARIA  6196
# 18  MANUTENCAO RECUPERACAO DE ESCADARIA, CANALETA ...  548
# 19  MANUTENCAO RECUPERACAO DE ESCADARIA, CANALETA ...  548
#
#    latitude_tratada DATA_DEMANDA DATA_ULT_SITUACAO  resolvido  dias_decorridos
# 0     INDETERMINADO   2008-03-14        2024-08-16          0              NaN
# 1     INDETERMINADO   2008-03-14        2024-08-16          0              NaN
# 2     INDETERMINADO   2008-04-10        2024-08-25          0              NaN
# 3     INDETERMINADO   2008-04-10        2024-08-25          0              NaN
# 4     INDETERMINADO   2008-08-15        2024-08-25          0              NaN
# 5     INDETERMINADO   2008-08-15        2024-08-25          0              NaN
# 6     INDETERMINADO   2008-09-15        2024-08-25          0              NaN
# 7     INDETERMINADO   2008-09-15        2024-08-25          0              NaN
# 8     INDETERMINADO   2009-03-10        2024-08-25          0              NaN
# 9     INDETERMINADO   2009-03-10        2024-08-25          0              NaN
# 10    INDETERMINADO   2009-10-06        2024-08-25          0              NaN
# 11    INDETERMINADO   2009-10-06        2024-08-25          0              NaN
# 12    INDETERMINADO   2010-01-07        2024-01-12          1           5118.0
# 13    INDETERMINADO   2010-01-07        2024-01-12          1           5118.0
# 14    INDETERMINADO   2010-01-20        2024-01-19          1           5112.0
# 15    INDETERMINADO   2010-01-20        2024-01-19          1           5112.0
# 16    INDETERMINADO   2010-03-01        2024-01-29          1           5082.0
# 17    INDETERMINADO   2010-03-01        2024-01-29          1           5082.0
# 18    INDETERMINADO   2010-04-16        2024-08-19          1           5239.0
# 19    INDETERMINADO   2010-04-16        2024-08-19          1           5239.0
